# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from bs4) (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.0.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1279 sha256=6b30636d8f7cd9a11ac51bceaf6c3b74950fe36c5ee5128aa21f0a8136b554f6
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\75\78\21\68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\user\anaconda3\lib\site-packages (4.5.2)

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.1.3-py3-none-any.whl (968 kB)
#      |████████████████████████████████| 968 kB 6.9 MB/s
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting urllib3[secure,socks]~=1.26
#   Downloading urllib3-1.26.8-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 57.2 MB/s
# Collecting trio~=0.17
#   Downloading trio-0.20.0-py3-none-any.whl (359 kB)
#      |████████████████████████████████| 359 kB 53.4 MB/s
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting outcome
#   Downloading outcome-1.1.0-py2.py3-none-any.whl (9.7 kB)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Collecting pyOpenSSL>=0.14
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.7 MB/s
# Collecting cryptography>=1.3.4
#   Downloading cryptography-36.0.2-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 40.9 MB/s
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (2.21)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.6 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium) (3.10.0.2)
# Installing collected packages: sniffio, outcome, h11, cryptography, async-generator, wsproto, urllib3, trio, pyOpenSSL, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.8 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed async-generator-1.10 cryptography-36.0.2 h11-0.13.0 outcome-1.1.0 pyOpenSSL-22.0.0 selenium-4.1.3 sniffio-1.2.0 trio-0.20.0 trio-websocket-0.9.2 urllib3-1.26.8 wsproto-1.1.0

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (2.24.0)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.8
#     Uninstalling urllib3-1.26.8:
#       Successfully uninstalled urllib3-1.26.8
# Successfully installed urllib3-1.25.11
# ERROR: selenium 4.1.3 has requirement urllib3[secure,socks]~=1.26, but you'll have urllib3 1.25.11 which is incompatible.

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (4.47.0)

# %%
from selenium.webdriver.common.keys import Keys
import datetime
import re
import tqdm
from selenium import webdriver
import time
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
import random
import math
import requests
import pandas as pd
from selenium.common.exceptions import NoSuchElementException as NSEE
import re

# %%
# !dir
# Out:
# sample_data

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')  # 브라우저 창을 띄우지 않는 옵션
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
chrome_options.add_argument(
    'user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36')  # headless 옵션으로 서버에서 차단당하지 않기위해 넣는 옵션
# driver = webdriver.Chrome('C:/Users/brain/Desktop/crawling/code/chromedriver.exe', options=chrome_options) # 입력


driver = webdriver.Chrome('./chromedriver.exe')  # chrome driver 입력
driver.implicitly_wait(30)
_keyword = 'beautiful' # 검색할 키워드
url = 'https://www.instagram.com/explore/tags/'+_keyword
# url = 'https://www.instagram.com/explore/tags/cat/'
driver.get(url)
driver.implicitly_wait(30)
time.sleep(4)

try:
    driver.find_element(By.XPATH, '//*[@id="react-root"]/section/nav/div[2]/div/div/div[3]/div/span/a[1]/button').click()
except:
    print("하..")
# Out:
# <ipython-input-7-cc1d04e6d515>:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver.exe')  # chrome driver 입력

# %%
def login():  # 로그인
    driver.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[1]/div/label/input').click()
    driver.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[1]/div/label/input').send_keys('kisnuyh_97')  # ID
    driver.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[2]/div/label/input').click()
    driver.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[2]/div/label/input').send_keys('!wys159753')  # PWD
    driver.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[3]/button').click()
    time.sleep(5)
    driver.find_element(By.XPATH, '//*[@id="react-root"]/section/main/div/div/div/div/button').click()
    # pyautogui.click(472, 642)
    time.sleep(5)


#     pyautogui.click(487, 719)
#     time.sleep(5)

# %%
time.sleep(3)
login()

# %%
#driver.find_element(By.XPATH, '//*[@id="react-root"]/section/main/article/div[1]/div/div/div[1]/div[1]/a/div/div[2]').click()
driver.find_element_by_css_selector('div.v1Nh3.kIKUG._bz0w').click() #첫번째 게시물 열기
time.sleep(5)
# Out:
# <ipython-input-10-ee6a85ed3d09>:2: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   driver.find_element_by_css_selector('div.v1Nh3.kIKUG._bz0w').click() #첫번째 게시물 열기

# %%
regex = re.compile("["
        "a-z"
        "A-Z"
        "0-9"
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"# flags (iOS)
                   " "
                   " "
                   '⠀'
                   "\0020"
                   "-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…：_·"
                   "’♥"
                   "③②①•♡‥←」「„”“،～}{？。、）（！ 　้"
�‍👨🏾 👩🏼‍🤝‍👨🏿 👩🏽‍🤝‍👨🏻 👩🏽‍🤝‍👨🏼 👩🏽‍🤝‍👨🏾 👩🏽‍🤝‍👨🏿 👩🏾‍🤝‍👨🏻 👩🏾‍🤝‍👨🏼 👩🏾‍🤝‍👨🏽 👩🏾‍🤝‍👨🏿 👩🏿‍🤝‍👨🏻 👩🏿‍🤝‍👨🏼 👩🏿‍🤝‍👨🏽 👩🏿‍🤝‍👨🏾 👨🏻‍🤝‍👨🏼 👨🏻‍🤝‍👨🏽 👨🏻‍🤝‍👨🏾 👨🏻‍🤝‍👨🏿 👨🏼‍🤝‍👨🏻 👨🏼‍🤝‍👨🏽 👨🏼‍🤝‍👨🏾 👨🏼‍🤝‍👨🏿 👨🏽‍🤝‍👨🏻 👨🏽‍🤝‍👨🏼 👨🏽‍🤝‍👨🏾 👨🏽‍🤝‍👨🏿 👨🏾‍🤝‍👨🏻 👨🏾‍🤝‍👨🏼 👨🏾‍🤝‍👨🏽 👨🏾‍🤝‍👨🏿 👨🏿‍🤝‍👨🏻 👨🏿‍🤝‍👨🏼 👨🏿‍🤝‍👨🏽 👨🏿‍🤝‍👨🏾 👩‍❤️‍💋‍👨 👨‍❤️‍💋‍👨 👩‍❤️‍💋‍👩 👩‍❤️‍👨 👨‍❤️‍👨 👩‍❤️‍👩 👨‍👩‍👦 👨‍👩‍👧 👨‍👩‍👧‍👦 👨‍👩‍👦‍👦 👨‍👩‍👧‍👧 👨‍👨‍👦 👨‍👨‍👧 👨‍👨‍👧‍👦 👨‍👨‍👦‍👦 👨‍👨‍👧‍👧 👩‍👩‍👦 👩‍👩‍👧 👩‍👩‍👧‍👦 👩‍👩‍👦‍👦 👩‍👩‍👧‍👧 👨‍👦 👨‍👦‍👦 👨‍👧 👨‍👧‍👦 👨‍👧‍👧 👩‍👦 👩‍👦‍👦 👩‍👧 👩‍👧‍👦 👩‍👧‍👧 🐕‍🦺 🐈‍⬛ 🐻‍❄️ 🏳️‍🌈 🏳️‍⚧️ 🏴‍☠️"
                   "\ufe0f"
                   "\n"
                   "주수정됨분시간일월"
                           "]+", flags=re.UNICODE)

# %%
all = []
exc = set()
count = 1000 # 몇개의 게시물을 할건지
for i in tqdm.tqdm(range(count)):
    check = 1
    try:
        hashtags = []
        sources = []
        image_list = []
      # 올린사람 ID
        try:
            upload_id_object = driver.find_element(By.XPATH, '/html/body/div[6]/div[3]/div/article/div/div[2]/div/div/div[1]/div/header/div[2]/div[1]/div[1]/div/span/a')
            upload_id = upload_id_object.text
        except:
            upload_id = None

        for j in all:
            if upload_id in j:
                check = 0
                break
        if(check == 0):
            time.sleep(60)
            next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
            next_arrow_btn.send_keys(Keys.ENTER)
            continue

    
        #해시태그
        try:
            data = driver.find_elements_by_css_selector('a.xil3i') # 해쉬태그 정보 저장
            for j in range(len(data)):
                hashtags.append(data[j].text.replace("#","")) # '#'없애기
            contents_html = driver.page_source
            contents_bs = BeautifulSoup(contents_html, 'lxml')
            contents = contents_bs.find('div', {'class', 'C4VMK'}).get_text()
            for k in contents:
                if regex.findall(k) == []:
                    check = 0
                    exc.add(k)
            if check == 0:
                time.sleep(60)
                next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
                next_arrow_btn.send_keys(Keys.ENTER)
                continue
        except:
            print("해시태그 저장 실패"+str(i))
  
     # 위치정보
        overlapphoto = driver.find_elements_by_class_name("Yi5aA")
        if (len(overlapphoto) == 0):
            try:
                image = driver.find_element_by_css_selector('div._97aPb.C2dOX   img.FFVAD')
                images = image.get_attribute('src')
                image_list.append(images)
            except:
                images = "error"
                print("이미지 저장 실패"+str(i))
        else :
            for n in range(len(overlapphoto)):
                try:
                    image = driver.find_element_by_css_selector('div._97aPb.C2dOX   img.FFVAD')
                    images = image.get_attribute('src')
                    image_list.append(images)
                except:
                    images = "error"
                    print("이미지 저장 실패"+str(i))
                try:
                    driver.find_element_by_class_name("coreSpriteRightChevron").click()
                except:
                    continue

        try:
            location_object = driver.find_element(By.XPATH, '/html/body/div[6]/div[3]/div/article/div/div[2]/div/div/div[1]/div/header/div[2]/div[2]/div/div[2]/div/a')
            location_info = location_object.text
            location_href = location_object.get_attribute("href")
        except:
            location_info = None
            location_href = None




        # 날짜
        try:
            date_object = driver.find_element(By.XPATH, '/html/body/div[6]/div[3]/div/article/div/div[2]/div/div/div[2]/div[1]/ul/div/li/div/div/div[2]/div[2]/div/time')
            date_text = date_object.text
            date_time = date_object.get_attribute("datetime")
            date_title = date_object.get_attribute("title")
        except:
            date_text = None
            date_time = None
            date_title = None
        

        
            
        all.append([upload_id,date_time,hashtags,contents,image_list,location_info,location_href])
        
        if (i+1)%10 == 0: 
            print('{}번째 게시물 완료'.format(i+1))
        print("성공한 사진의 수"+str(len(all)))
        next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
        next_arrow_btn.send_keys(Keys.ENTER)
        
        time.sleep(3)
        
    except AttributeError:
        print("pass"+str(i))
        next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
        next_arrow_btn.send_keys(Keys.ENTER)
        continue
# Out:
#   0%|                                                                                         | 0/1000 [00:00<?, ?it/s]<ipython-input-12-66ce280e836f>:30: DeprecationWarning: find_elements_by_css_selector is deprecated. Please use find_elements(by=By.CSS_SELECTOR, value=css_selector) instead
#   data = driver.find_elements_by_css_selector('a.xil3i') # 해쉬태그 정보 저장
# <ipython-input-12-66ce280e836f>:42: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
#   0%|                                                                              | 1/1000 [01:00<16:46:33, 60.45s/it]<ipython-input-12-66ce280e836f>:49: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   overlapphoto = driver.find_elements_by_class_name("Yi5aA")
# <ipython-input-12-66ce280e836f>:52: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   image = driver.find_element_by_css_selector('div._97aPb.C2dOX   img.FFVAD')
# <ipython-input-12-66ce280e836f>:101: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
#   1%|▍                                                                             | 6/1000 [06:43<18:02:48, 65.36s/it]<ipython-input-12-66ce280e836f>:61: DeprecationWarning: find_element_by_css_selector is deprecated. Please use find_element(by=By.CSS_SELECTOR, value=css_selector) instead
#   image = driver.find_element_by_css_selector('div._97aPb.C2dOX   img.FFVAD')
# <ipython-input-12-66ce280e836f>:68: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   driver.find_element_by_class_name("coreSpriteRightChevron").click()
#   1%|▌                                                                             | 7/1000 [07:50<18:31:42, 67.17s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-66ce280e836f> in <module>
#     102         next_arrow_btn.send_keys(Keys.ENTER)
#     103
# --> 104         time.sleep(3)
#     105
#     106     except AttributeError:
#
# KeyboardInterrupt:

# %%
# all = []
# count = 1 # 몇개의 게시물을 할건지
# for i in tqdm.tqdm(range(count)):
#     try:
#         hashtags = []
#         sources = []
#         image_list = []
#       # 올린사람 ID
#         try:
#             upload_id_object = driver.find_element(By.XPATH, '/html/body/div[6]/div[3]/div/article/div/div[2]/div/div/div[1]/div/header/div[2]/div[1]/div[1]/div/span/a')
#             upload_id = upload_id_object.text
#         except:
#             upload_id = None

#         for j in all:
#           if upload_id in j:
#             continue
    
#         #해시태그
#         try:
#             data = driver.find_elements_by_css_selector('a.xil3i') # 해쉬태그 정보 저장
#             for j in range(len(data)):
#                 hashtags.append(data[j].text.replace("#","")) # '#'없애기
#             contents_html = driver.page_source
#             contents_bs = BeautifulSoup(contents_html, 'lxml')
#             contents = contents_bs.find('div', {'class', 'C4VMK'}).get_text()
#             for k in contents:
#                 if regex.findall(k) == []:
#                     print("이새끼 오류임'"+k+"'")
#                     time.sleep(60)
#                     next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
#                     next_arrow_btn.send_keys(Keys.ENTER)
#                     break
#         except:
#             print("해시태그 저장 실패"+str(i))
  
#      # 위치정보
#         overlapphoto = driver.find_elements_by_class_name("Yi5aA")
#         if (len(overlapphoto) == 0):
#             try:
#                 image = driver.find_element_by_css_selector('div._97aPb.C2dOX   img.FFVAD')
#                 images = image.get_attribute('src')
#                 image_list.append(images)
#             except:
#                 images = "error"
#                 print("이미지 저장 실패"+str(i))
#         else :
#             for n in range(len(overlapphoto)):
#                 try:
#                     image = driver.find_element_by_css_selector('div._97aPb.C2dOX   img.FFVAD')
#                     images = image.get_attribute('src')
#                     image_list.append(images)
#                 except:
#                     images = "error"
#                     print("이미지 저장 실패"+str(i))
#                 try:
#                     driver.find_element_by_class_name("coreSpriteRightChevron").click()
#                 except:
#                     continue

#         try:
#             location_object = driver.find_element(By.XPATH, '/html/body/div[6]/div[3]/div/article/div/div[2]/div/div/div[1]/div/header/div[2]/div[2]/div/div[2]/div/a')
#             location_info = location_object.text
#             location_href = location_object.get_attribute("href")
#         except:
#             location_info = None
#             location_href = None




#         # 날짜
#         try:
#             date_object = driver.find_element(By.XPATH, '/html/body/div[6]/div[3]/div/article/div/div[2]/div/div/div[2]/div[1]/ul/div/li/div/div/div[2]/div[2]/div/time')
#             date_text = date_object.text
#             date_time = date_object.get_attribute("datetime")
#             date_title = date_object.get_attribute("title")
#         except:
#             date_text = None
#             date_time = None
#             date_title = None
        

        
            
#         all.append([upload_id,date_time,hashtags,contents,image_list,location_info,location_href])
        
#         if (i+1)%10 == 0: 
#             print('{}번째 게시물 완료'.format(i+1))
#         next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
#         next_arrow_btn.send_keys(Keys.ENTER)
        
#         time.sleep(3)
        
#     except AttributeError:
#         print("pass"+str(i))
#         next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
#         next_arrow_btn.send_keys(Keys.ENTER)
#         continue

# %%
# image = driver.find_element_by_css_selector('div._97aPb.C2dOX   img.FFVAD')
# image_url=image.get_attribute('src')
# image_url

# %%
contents
# Out:
# "mycutiepiecatsWhat would you name them?? ❤️Dm for getting featured 📩.. '.. From 📸 @catteryshadowsmemory... Follow @mycutiepiecats for more ....#britishsoul_britishshorthair#britishsoul#britishshorthair#britishcat#cat#cats#catsforever#catlife#catlover#catloversclub#catworldwide#catgram#cat_features#instagram#topcatphoto#igmeow#meow#yourcatphoto#catselfie#sweetcat#exellent_kittens#exellent_cats#catlogic#meow#instakitten#kittens#allmeowphotos#britishshorthairworld7시간"

# %%
# next_arrow_btn = driver.find_element_by_css_selector("div.l8mY4.feth3 > .wpO6b ") #다음 게시물로 이동
# next_arrow_btn.send_keys(Keys.ENTER)

# %%
df = pd.DataFrame(all,columns=["upload_id","date_time","hashtags","contents","images","location_info","location_href"])

# %%
filename = datetime.datetime.now().strftime("%m월 %d일 %H시%M분")
df.to_csv(_keyword+filename+".csv",encoding="UTf-8-sig")

# %%
# overlapphoto = driver.find_elements_by_class_name("Yi5aA")
# if (len(overlapphoto) == 0):
#     #이미지주소따기
#     print("A")
# else :
#     for n in range(len(overlapphoto)):
#         temp = n+1
#         #이미지주소따기
#         try:
#             driver.find_element_by_class_name("coreSpriteRightChevron").click()
#         except NoSuchElementException:
#             break
# Out:
# /var/folders/2x/h2z3m2816w39tgg6fjsqp8l00000gn/T/ipykernel_55625/717645566.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   overlapphoto = driver.find_elements_by_class_name("Yi5aA")
# /var/folders/2x/h2z3m2816w39tgg6fjsqp8l00000gn/T/ipykernel_55625/717645566.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_class_name("coreSpriteRightChevron").click()
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [44], in <module>
#       9 try:
# ---> 10     driver.find_element_by_class_name("coreSpriteRightChevron").click()
#      11 except NoSuchElementException:
#
# File ~/miniforge3/envs/tf25/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:760, in WebDriver.find_element_by_class_name(self, name)
#     755 warnings.warn(
#     756     "find_element_by_* commands are deprecated. Please use find_element() instead",
#     757     DeprecationWarning,
#     758     stacklevel=2,
#     759 )
# --> 760 return self.find_element(by=By.CLASS_NAME, value=name)
#
# File ~/miniforge3/envs/tf25/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:1244, in WebDriver.find_element(self, by, value)
#    1242     value = '[name="%s"]' % value
# -> 1244 return self.execute(Command.FIND_ELEMENT, {
#    1245     'using': by,
#    1246     'value': value})['value']
#
# File ~/miniforge3/envs/tf25/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:424, in WebDriver.execute(self, driver_command, params)
#     423 if response:
# --> 424     self.error_handler.check_response(response)
#     425     response['value'] = self._unwrap_value(
#     426         response.get('value', None))
#
# File ~/miniforge3/envs/tf25/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".coreSpriteRightChevron"}
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# 0   chromedriver                        0x000000010520f370 chromedriver + 4420464
# 1   chromedriver                        0x00000001051a6940 chromedriver + 3991872
# 2   chromedriver                        0x0000000104e06548 chromedriver + 189768
# 3   chromedriver                        0x0000000104e34ef8 chromedriver + 380664
# 4   chromedriver                        0x0000000104e5dbfc chromedriver + 547836
# 5   chromedriver                        0x0000000104e2a248 chromedriver + 336456
# 6   chromedriver                        0x00000001051d3548 chromedriver + 4175176
# 7   chromedriver                        0x00000001051e995c chromedriver + 4266332
# 8   chromedriver                        0x00000001051ee660 chromedriver + 4286048
# 9   chromedriver                        0x00000001051ea124 chromedriver + 4268324
# 10  chromedriver                        0x00000001051c953c chromedriver + 4134204
# 11  chromedriver                        0x0000000105201eb0 chromedriver + 4366000
# 12  chromedriver                        0x0000000105202014 chromedriver + 4366356
# 13  chromedriver                        0x0000000105215a6c chromedriver + 4446828
# 14  libsystem_pthread.dylib             0x00000001c1cb626c _pthread_start + 148
# 15  libsystem_pthread.dylib             0x00000001c1cb108c thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Input In [44], in <module>
#       9 try:
#      10     driver.find_element_by_class_name("coreSpriteRightChevron").click()
# ---> 11 except NoSuchElementException:
#      12     break
#
# NameError: name 'NoSuchElementException' is not defined

# %%
import re

# %%
regex = re.compile("["
        "a-z"
        "A-Z"
        "0-9"
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"# flags (iOS)
                   " "
                   "-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…"
                   "\n"
                   "주수정됨분"
                           "]+", flags=re.UNICODE)

# %%
regex = re.compile("^a-z", flags=re.UNICODE)

# %%
regex.findall(contents)
# Out:
# []

# %%
for i in contents:
    if regex.findall(i) == []:
        print(i)
# Out:
# カ
# プ
# レ
# ー
# ゼ
# デ
# ィ
# ブ
# ラ
# タ
# 新
# し
# い
# 美
# 味
# し
# い
# 美
# 味
# し
# い
# お
# 店
# い
# ら
# っ
# し
# ゃ
# い
# ま
# せ

# %%
contents
# Out:
# "mycutiepiecatsWhat would you name them?? ❤️Dm for getting featured 📩.. '.. From 📸 @catteryshadowsmemory... Follow @mycutiepiecats for more ....#britishsoul_britishshorthair#britishsoul#britishshorthair#britishcat#cat#cats#catsforever#catlife#catlover#catloversclub#catworldwide#catgram#cat_features#instagram#topcatphoto#igmeow#meow#yourcatphoto#catselfie#sweetcat#exellent_kittens#exellent_cats#catlogic#meow#instakitten#kittens#allmeowphotos#britishshorthairworld7시간"

# %%
for i,k in enumerate(contents):
    if regex.findall(k) == []:
        print("이새끼 오류임'"+k+"'")
        print(i)
# Out:
# 이새끼 오류임'️'
# 42

# %%
print(contents[41])
print(contents[42])
a = contents[42]
# Out:
# ❤
# ️

# %%
b =  "이새끼 오류임' '"
print(b[8])
print(b[8].encode('css'))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_14836/312881411.py in <module>
#       1 b =  "이새끼 오류임' '"
#       2 print(b[8])
# ----> 3 print(b[8].encode('css'))
#
# LookupError: unknown encoding: css

# %%
len(a)
# Out:
# 1

# %%
a.encode('cp949')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_23324/2447905695.py in <module>
# ----> 1 a.encode('cp949')
#
# UnicodeEncodeError: 'cp949' codec can't encode character '\ufe0f' in position 0: illegal multibyte sequence

# %%
print("\ufe0f")
# Out:
# ️

# %%
df2 = pd.DataFrame(exc)

# %%
df2.to_csv("exc.csv",encoding="utf-8-sig")

# %%
exc
# Out:
# {'á', 'î', 'ó', '―', '\u2028'}
